# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# %%
df = pd.read_csv("student_score.csv")

# %%
df.head()
# Out:
#    Hours  Score
# 0    1.0     18
# 1    2.0     25
# 2    3.0     32
# 3    4.0     40
# 4    5.0     47

# %%
df.tail()
# Out:
#     Hours  Score
# 15    7.5     67
# 16    8.5     74
# 17    9.5     82
# 18    1.5     21
# 19    5.8     53

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Hours   20 non-null     float64
#  1   Score   20 non-null     int64
# dtypes: float64(1), int64(1)
# memory usage: 452.0 bytes

# %%
df.describe()
# Out:
#            Hours      Score
# count  20.000000  20.000000
# mean    5.515000  51.400000
# std     2.739434  20.752679
# min     1.000000  18.000000
# 25%     3.375000  35.000000
# 50%     5.650000  52.000000
# 75%     7.625000  67.750000
# max    10.000000  85.000000

# %%
df.shape
# Out:
# (20, 2)

# %%
x = df[["Hours"]]
y = df[["Score"]]

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
## Build Model
model = LinearRegression()

## Train Model
model.fit(x_train, y_train)

## Test Model
y_pred = model.predict(x_test)

# %%
## Evaluation 

print("Mean Absolute Error: ", mean_absolute_error(y_test, y_pred))
print("Mean Squared Error: ", mean_squared_error(y_test, y_pred))
print("R2 Score: ", r2_score(y_test, y_pred))
# Out:
# Mean Absolute Error:  0.6392995160672621
# Mean Squared Error:  0.46429905914593145
# R2 Score:  0.9993695871566247

# %%
## Model parameter

print("Slope: ", model.coef_[0])
print("Intercept: ", model.intercept_)
# Out:
# Slope:  [7.59502837]
# Intercept:  [9.38555861]

# %%
## Predict new value

hours = [[12]]
prediction = model.predict(hours)
print("A new predicted score for 12 study hours is: ", prediction[0])
# Out:
# A new predicted score for 12 study hours is:  [100.52589911]
# /Users/ayeshasiddiqha/AIProjects/.venv/lib/python3.14/site-packages/sklearn/utils/validation.py:2827: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
# Line plot
plt.plot(x, model.predict(x))

# Labels and title
plt.xlabel("Hours")
plt.ylabel("Predicted Score")
plt.title("Simple Line Plot for Linear Regression")

# Display
plt.show()

# %%
# Scatter plot
plt.scatter(x, model.predict(x))

# Labels and title
plt.xlabel("Hours")
plt.ylabel("Predicted Score")
plt.title("Simple Scatter Plot for Linear Regression")

plt.show()
